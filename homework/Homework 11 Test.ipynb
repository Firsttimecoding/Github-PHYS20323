# %%
residual = data['Y']-linear(data['X'],*popt)
x = np.linspace(5,20,1000)

fig = plt.figure(figsize=(15,10))
ax = fig.add_subplot(111)
ax.scatter(data['X'],residual,s=15,c='black')
ax.plot(x,x*0.0,color='purple')
ax.set_xlim(6,16)

outlier = np.absolute(residual)>0.2
ax.scatter(data['X'][outlier],residual[outlier],s=60,edgecolor='cyan',facecolor='none')

residual = data['LogG']-poly2(x_plot, param1, param2, param3)
x = np.linspace(5,20,1000)

fig_dude = plt.figure(figsize=(15,10))
ax_dude = fig.add_subplot(111)
ax_dude.scatter(data['TEFF'],residual,s=15,c='black')
ax_dude.plot(x,x*0.0,color='purple')
ax_dude.set_xlim(6,16)

outlier = np.absolute(residual)>0.2
ax_dude.scatter(xlim,residual[outlier],s=60,edgecolor='red',facecolor='none')
