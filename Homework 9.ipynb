# %% [markdown]
# # Homework 9

# %% [markdown]
# ## Problem 1

# %%
.00000000004321-.00000000005432
# Out:
# -1.1110000000000001e-11

# %%
from numpy import random

prize = random.randint(1,4)
# Out:
# 3
# 2
# 1
# 1
# 1
# 1
# 1
# 3
# 1
# 2

# %%
random.choice([1, 2, 3])
# Out:
# 1

# %%
doors = [0, 1, 2]
nwin = 0
nlose = 0
for i in range(1,51):
    prize = random.randint(0,3)
    choice_1 = random.randint(0,3)

    ## first, always change doors

    if choice_1 == prize:
        doors.remove(choice_1)
        door_remove = random.choice(doors) ## removed door is random door not prize door
        doors.remove(door_remove) ## removes removed door
        choice_2 = doors[0] ## other door is chosen
    else: ## first choice is not prize door
        doors.remove(choice_1) ## removes first choice
        doors.remove(prize) ## removes prize door
        door_remove = doors[0] ## door removed is the remaining door
        choice_2 = prize ## the remaining door is chosen, which is the prize door
    if choice_2 == prize:
        win = True
    else:
        win = False

    if win == True:
        print("YOU WIN!!!")
    else:
        print("YOU LOSE!!!")
    if win == True:
        nwin += 1
    else:
        nlose+= 1
probability_of_win = nwin / 50
probability_of_lose = nlose / 50
# Out:
# YOU LOSE!!!
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-111-8a5789752473> in <module>
#       9
#      10     if choice_1 == prize:
# ---> 11         doors.remove(choice_1)
#      12         door_remove = random.choice(doors) ## removed door is random door not prize door
#      13         doors.remove(door_remove) ## removes removed door
#
# ValueError: list.remove(x): x not in list

# %%
## now, always keep the same door

doors = [1, 2, 3]
nwin = 0
nlose = 0
for i in range(1, 51):
    prize = random.randint(1,4)
    choice_1 = random.randint(1,4)

    if choice_1 == prize:
        win = True
    else: 
        win = False
    if win == True:
        print("YOU WIN!!!")
    else:
        print("YOU LOSE!!!")
    if win == True:
        nwin += 1
    else:
        nlose+= 1
probability_of_win = nwin / 50
probability_of_lose = nlose / 50
print(probability_of_win, probability_of_lose)
# Out:
# YOU LOSE!!!
# YOU LOSE!!!
# YOU LOSE!!!
# YOU LOSE!!!
# YOU LOSE!!!
# YOU LOSE!!!
# YOU LOSE!!!
# YOU WIN!!!
# YOU WIN!!!
# YOU WIN!!!
# YOU WIN!!!
# YOU LOSE!!!
# YOU LOSE!!!
# YOU LOSE!!!
# YOU LOSE!!!
# YOU LOSE!!!
# YOU LOSE!!!
# YOU LOSE!!!
# YOU LOSE!!!
# YOU LOSE!!!
# YOU LOSE!!!
# YOU LOSE!!!
# YOU LOSE!!!
# YOU LOSE!!!
# YOU LOSE!!!
# YOU LOSE!!!
# YOU LOSE!!!
# YOU WIN!!!
# YOU WIN!!!
# YOU LOSE!!!
# YOU LOSE!!!
# YOU LOSE!!!
# YOU LOSE!!!
# YOU LOSE!!!
# YOU WIN!!!
# YOU LOSE!!!
# YOU LOSE!!!
# YOU WIN!!!
# YOU LOSE!!!
# YOU WIN!!!
# YOU WIN!!!
# YOU LOSE!!!
# YOU LOSE!!!
# YOU WIN!!!
# YOU WIN!!!
# YOU WIN!!!
# YOU WIN!!!
# YOU WIN!!!
# YOU LOSE!!!
# YOU LOSE!!!
# 0.3 0.7

# %%
 if choice_2 = prize:
        win = True
    else:
        lose = True
else:
    doors.remove(choice_1)
    doors.remove(prize)
    door_removed = random.choice(doors)
    doors.append(choice)

# %%
for i in range(1, 10):
    doors = [1, 2, 3]
    choice_1 = random.randint(1, 4)
    doors.remove(choice_1)
    door_remove = random.choice(doors)
    print(doors, door_remove)
# Out:
# [1, 2] 2
# [2, 3] 3
# [1, 2] 1
# [1, 2] 2
# [1, 2] 1
# [2, 3] 2
# [1, 2] 1
# [2, 3] 3
# [1, 3] 1
