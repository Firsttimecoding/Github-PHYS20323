# %%
import numpy as np

def sn(n):
    if n == 1:
        return(1)
    else:
        sn = (n) + sn(n-1)
        return(sn)
sn(6)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-12-c56a0b35fb13> in <module>
#       7         sn = (n) + sn(n-1)
#       8         return(sn)
# ----> 9 sn(6)
#
# <ipython-input-12-c56a0b35fb13> in sn(n)
#       5         return(1)
#       6     else:
# ----> 7         sn = (n) + sn(n-1)
#       8         return(sn)
#       9 sn(6)
#
# UnboundLocalError: local variable 'sn' referenced before assignment

# %%
# Out:
# 720.0
