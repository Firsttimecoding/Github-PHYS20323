# %% [markdown]
# ## This is sooooooo coooooooollllllllllll!!!!!!!!!!

# %%
a = "hello, world!"

# %%
print(a)
# Out:
# hello, world!

# %%
a.split()
# Out:
# ['hello,', 'world!']

# %%
r = a.split()

# %%
print(r)
# Out:
# ['hello,', 'world!']

# %%
out = r[0] + " " + r[1] + " " + r[0]

# %%
print(out)
# Out:
# hello, world! hello,

# %%
dude = "This is so cool!"

# %%
b = dude.split()

# %%
print(b)
# Out:
# ['This', 'is', 'so', 'cool!']

# %%
i = 2
j = 3
k = 4

# %%
print(i+j+k)
# Out:
# 9

# %%
print(i,j,k)
# Out:
# 2 3 4

# %%
a = 2.2
b = 3.3
c = 4.4

# %%
print(a,b,c)
# Out:
# 2.2 3.3 4.4

# %%
d = complex(4,2.2)

# %%
print(d)
# Out:
# (4+2.2j)

# %%
1+2-complex(1,2.2)
# Out:
# (2-2.2j)

# %%
x = 1+2-complex(1,2.2)

# %%
x**2
# Out:
# (-0.8400000000000007-8.8j)

# %%
x/2
# Out:
# (1-1.1j)

# %%
3/2
# Out:
# 1.5

# %%
4/3
# Out:
# 1.3333333333333333

# %%
4//3
# Out:
# 1

# %%
(4**3)**(2/3)
# Out:
# 15.999999999999998

# %%
3*4.4
# Out:
# 13.200000000000001

# %%
3.444*complex(4.,1.)
# Out:
# (13.776+3.444j)

# %%
complex(1.1,2.2) - complex(3.445, 23232323)
# Out:
# (-2.3449999999999998-23232320.8j)

# %%
s = "'righteousness' 'justice' 'mercy' 'truth'"

# %%
print(s)
# Out:
# 'righteousness' 'justice' 'mercy' 'truth'

# %%
t = '"Hello," said John. "I know what you\'re up to."'
print(t)
# Out:
# "Hello," said John. "I know what you're up to."

# %%
s[36]
# Out:
# 'r'

# %%
len(s)
# Out:
# 41

# %%
w = "hello," + " " + "brother" 
print(w)
# Out:
# hello, brother

# %%
w.upper()
# Out:
# 'HELLO, BROTHER'

# %%
w.split()
# Out:
# ['hello,', 'brother']

# %%
w.index('er')
# Out:
# 12

# %%
li = [1, 2.22, 3, 'victory']
print(li)
# Out:
# [1, 2.22, 3, 'victory']

# %%
li[3]
# Out:
# 'victory'

# %%
li[1]
# Out:
# 2.22

# %%
len(li)
# Out:
# 4

# %%
li[2] = "battle"
print(li)
# Out:
# [1, 2.22, 'battle', 'victory']

# %%
li.append(444)
print(li)
# Out:
# [1, 2.22, 'battle', 'victory', 444]

# %%
li.insert(1,2)
print(li)
# Out:
# [1, 2, 2, 2.22, 2, 'battle', 'victory', 2, 444, 2, 2]

# %%
li.remove(2)
print(li)
# Out:
# [1, 2.22, 'battle', 'victory', 444]

# %%
li[-3]
# Out:
# 'battle'

# %%
li[:3]
# Out:
# [1, 2.22, 'battle']

# %%
li[3:]
# Out:
# ['victory', 444]

# %%
li[0:2]
# Out:
# [1, 2.22]

# %%
li[0:5]
# Out:
# [1, 2.22, 'battle', 'victory', 444]

# %%
li[::2]
# Out:
# [1, 'battle', 444]

# %%
f = "Hello, egg world!"

# %%
g = f.split()

# %%
dude = g[0] + " " + g[2]
print(dude)
# Out:
# Hello, world!

# %%
li = ["Hello,", "egg", "world!"]

# %%
li[1]
# Out:
# 'egg'

# %%
dudette = li[0] + " " + li[2]
print(dudette)
# Out:
# Hello, world!

# %%
# Out:
# li[0]li[1]
